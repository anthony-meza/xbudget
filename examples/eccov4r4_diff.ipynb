# %%
# %load_ext autoreload
# %autoreload 2

# %%
import xarray as xr
import numpy as np
from scipy.interpolate import griddata
import xgcm
import matplotlib.pyplot as plt
import xbudget

from load_example_ecco_grid import * 
from eccov4r4_budget_diagnostics import * 
from xbudget.llc90 import * 
print("xarray:",  xr.__version__)
print("xgcm:", xgcm.__version__)
# Out:
# xarray: 2026.4.0
# xgcm: 0.1.dev617+gb29dfdecb

# %%
def calc_uv_bolus(ds, grid, allow_rechunk=True):
    psix = ds["GM_PsiX"].where(np.isfinite(ds["GM_PsiX"]), 0.0)
    psiy = ds["GM_PsiY"].where(np.isfinite(ds["GM_PsiY"]), 0.0)

    psix_u = psix * ds["dyG"]
    psiy_v = psiy * ds["dxG"]

    UBOL_TRSP = grid.diff(psix_u.chunk({"k_l": -1}), "Z", boundary="fill")
    VBOL_TRSP = grid.diff(psiy_v.chunk({"k_l": -1}), "Z", boundary="fill")

    psi_diff = diff_2d_flux_llc90(
        grid,
        psix_u.unify_chunks(),
        psiy_v.unify_chunks(),
        allow_rechunk=allow_rechunk,
    )

    WBOL_TRSP = psi_diff["X"] + psi_diff["Y"]

    UBOL_TRSP = UBOL_TRSP.where(ds["maskW"]).fillna(0.0)
    VBOL_TRSP = VBOL_TRSP.where(ds["maskS"]).fillna(0.0)
    WBOL_TRSP = WBOL_TRSP.fillna(0.0)

    UVELSTAR = UBOL_TRSP / (ds["drF"] * ds["dyG"])
    VVELSTAR = VBOL_TRSP / (ds["drF"] * ds["dxG"])
    WVELSTAR = WBOL_TRSP / ds["rA"]

    return xr.Dataset(
        {
            "UVELSTAR": UVELSTAR.rename("UVELSTAR"),
            "VVELSTAR": VVELSTAR.rename("VVELSTAR"),
            "WVELSTAR": WVELSTAR.rename("WVELSTAR"),
        }
    )

# %%
transport_ds_path = "../../example-ECCOV4r4-budget-terms/data/ECCO_transport_terms.zarr"

ds = xr.open_mfdataset(transport_ds_path, parallel = True, engine = "zarr").fillna(0.0).isel(time = slice(0, 12))

def get_trsp(ds, vel):
    if "i_g" in vel.dims:
        trsp = vel.fillna(0.0) * ds["drF"] * ds["dyG"]
        return trsp.where(ds["maskW"]).fillna(0.0)

    if "j_g" in vel.dims:
        trsp = vel.fillna(0.0) * ds["drF"] * ds["dxG"]
        return trsp.where(ds["maskS"]).fillna(0.0)

    if "k_l" in vel.dims:
        trsp = vel.fillna(0.0) * ds["rA"]
        return trsp.fillna(0.0)

    raise ValueError("Expected velocity on `i_g`, `j_g`, or `k_l`.")

grid = construct_grid(ds)

bolus_velocities = calc_uv_bolus(ds, grid, allow_rechunk=True)

#dropping "bad downloaded velstars"
ds = ds.drop_vars(["UVELSTAR", "VVELSTAR", "WVELSTAR"])
ds = xr.merge([ds, bolus_velocities])
grid = construct_grid(ds)
# Out:
# /Users/anthonymeza/Library/CloudStorage/OneDrive-MassachusettsInstituteofTechnology/Documents/GitHub/xbudget/xbudget/llc90/operations.py:63: UserWarning: Dataset chunks are inconsistent; using unify_chunks()
#   warnings.warn("Dataset chunks are inconsistent; using unify_chunks()", UserWarning)
# /Users/anthonymeza/miniforge3/envs/docs_env_xbudget/lib/python3.12/site-packages/xarray/structure/chunks.py:183: PerformanceWarning: Increasing number of chunks by factor of 20
#   _, chunked_data = chunkmanager.unify_chunks(*unify_chunks_args)
# /var/folders/vt/sjvxnnwn7y51hx1c814wrxn80000gn/T/ipykernel_61217/430470777.py:26: FutureWarning: In a future version of xarray the default value for compat will change from compat='no_conflicts' to compat='override'. This is likely to lead to different results when combining overlapping variables with the same name. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set compat explicitly.
#   ds = xr.merge([ds, bolus_velocities])

# %%
URES_TRSP = get_trsp(ds, ds["UVELSTAR"] + ds["UVELMASS"]).unify_chunks().mean("time").compute()
VRES_TRSP = get_trsp(ds, ds["VVELSTAR"] + ds["VVELMASS"]).unify_chunks().mean("time").compute()

URES_TRSP = URES_TRSP.chunk({"tile": -1, "i_g":-1, "j":-1})
VRES_TRSP = VRES_TRSP.chunk({"tile": -1, "i":-1, "j_g":-1})

diff_UV_RES = diff_2d_flux_llc90(
    grid,
    URES_TRSP,
    VRES_TRSP,
    allow_rechunk=True,
)
# Out:
# /Users/anthonymeza/Library/CloudStorage/OneDrive-MassachusettsInstituteofTechnology/Documents/GitHub/xbudget/xbudget/llc90/operations.py:63: UserWarning: Dataset chunks are inconsistent; using unify_chunks()
#   warnings.warn("Dataset chunks are inconsistent; using unify_chunks()", UserWarning)
# /Users/anthonymeza/miniforge3/envs/docs_env_xbudget/lib/python3.12/site-packages/xarray/structure/chunks.py:183: PerformanceWarning: Increasing number of chunks by factor of 20
#   _, chunked_data = chunkmanager.unify_chunks(*unify_chunks_args)

# %%
UVRES_CONV = -(diff_UV_RES["X"] + diff_UV_RES["Y"]).compute()#.mean("time").compute()

# %%
def llc_hdiv_from_trsp(grid, Utrsp, Vtrsp):
    dUdx = grid.diff(
        {"X": Utrsp}, "X",
        other_component={"Y": Vtrsp},
    )

    dVdy = grid.diff(
        {"Y": Vtrsp}, "Y",
        other_component={"X": Utrsp},
    )

    return -(dUdx + dVdy)

UVRES_CONV2 = llc_hdiv_from_trsp(grid, URES_TRSP, VRES_TRSP).compute()#.mean("time").compute()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 14
#      10     )
#      11
#      12     return -(dUdx + dVdy)
#      13
# ---> 14 UVRES_CONV2 = llc_hdiv_from_trsp(grid, URES_TRSP, VRES_TRSP).compute()#.mean("time").compute()
#
# Cell In[7], line 2, in llc_hdiv_from_trsp(grid, Utrsp, Vtrsp)
#       1 def llc_hdiv_from_trsp(grid, Utrsp, Vtrsp):
# ----> 2     dUdx = grid.diff(
#       3         {"X": Utrsp}, "X",
#       4         other_component={"Y": Vtrsp},
#       5     )
#
# File ~/Library/CloudStorage/OneDrive-MassachusettsInstituteofTechnology/Documents/GitHub/xgcm/xgcm/grid.py:947, in Grid.diff(self, da, axis, **kwargs)
#     897 def diff(self, da, axis, **kwargs):
#     898     """
#     899     Difference neighboring points to the intermediate grid point.
#     900
#    (...)    945     >>> grid.diff(da, ["X", "Y"], fill_value={"X": 0, "Y": 100})
#     946     """
# --> 947     return self._1d_grid_ufunc_dispatch("diff", da, axis, **kwargs)
#
# File ~/Library/CloudStorage/OneDrive-MassachusettsInstituteofTechnology/Documents/GitHub/xgcm/xgcm/grid.py:689, in Grid._1d_grid_ufunc_dispatch(self, funcname, data, axis, to, keep_coords, metric_weighted, other_component, **kwargs)
#     686 else:
#     687     map_overlap = False
# --> 689 array = grid_ufunc(
#     690     self,
#     691     array,
#     692     axis=[(ax_name,)],
#     693     keep_coords=keep_coords,
#     694     dask=dask,
#     695     map_overlap=map_overlap,
#     696     other_component=other_component,
#     697     **remaining_kwargs,
#     698 )
#     700 if ax_metric_weighted:
#     701     metric = self.get_metric(array, ax_metric_weighted)
#
# File ~/Library/CloudStorage/OneDrive-MassachusettsInstituteofTechnology/Documents/GitHub/xgcm/xgcm/grid_ufunc.py:463, in GridUFunc.__call__(self, grid, axis, *args, **kwargs)
#     461 map_overlap = kwargs.pop("map_overlap", self.map_overlap)
#     462 pad_before_func = kwargs.pop("pad_before_func", self.pad_before_func)
# --> 463 return apply_as_grid_ufunc(
#     464     self.ufunc,
#     465     *args,
#     466     axis=axis,
#     467     grid=grid,
#     468     signature=self.signature,
#     469     boundary_width=self.boundary_width,
#     470     boundary=boundary,
#     471     dask=dask,
#     472     map_overlap=map_overlap,
#     473     pad_before_func=pad_before_func,
#     474     **kwargs,
#     475 )
#
# File ~/Library/CloudStorage/OneDrive-MassachusettsInstituteofTechnology/Documents/GitHub/xgcm/xgcm/grid_ufunc.py:767, in apply_as_grid_ufunc(func, axis, grid, signature, boundary_width, boundary, fill_value, keep_coords, dask, map_overlap, pad_before_func, other_component, *args, **kwargs)
#     764 # For most ufuncs we want to pad before applying, but for some (especially cumsum) we must apply then pad
#     765 # TODO could we bind a bunch of these arguments into a namedtuple/dataclass or something to save space?
#     766 if pad_before_func:
# --> 767     rechunked_padded_args = _pad_then_rechunk(
#     768         args,
#     769         grid,
#     770         in_core_dims,
#     771         boundary_width_real_axes,
#     772         boundary,
#     773         fill_value,
#     774         other_component,
#     775     )
#     776     results = _apply(
#     777         mapped_func,
#     778         rechunked_padded_args,
#    (...)    784         **kwargs,
#     785     )
#     786 else:  # pad after func
#
# File ~/Library/CloudStorage/OneDrive-MassachusettsInstituteofTechnology/Documents/GitHub/xgcm/xgcm/grid_ufunc.py:902, in _pad_then_rechunk(args, grid, in_core_dims, boundary_width_real_axes, boundary, fill_value, other_component)
#     885 padded_args = [
#     886     pad(
#     887         a,
#    (...)    894     for a, oc in zip(args, other_component)
#     895 ]
#     897 if any(
#     898     _has_chunked_core_dims(padded_arg, core_dims)
#     899     for padded_arg, core_dims in zip(padded_args, in_core_dims)
#     900 ):
#     901     # merge any lonely chunks on either end created by padding
# --> 902     rechunked_padded_args = _rechunk_to_merge_in_boundary_chunks(
#     903         padded_args,
#     904         args,
#     905         boundary_width_real_axes,
#     906         grid,
#     907     )
#     908 else:
#     909     rechunked_padded_args = padded_args
#
# File ~/Library/CloudStorage/OneDrive-MassachusettsInstituteofTechnology/Documents/GitHub/xgcm/xgcm/grid_ufunc.py:1023, in _rechunk_to_merge_in_boundary_chunks(padded_args, original_args, boundary_width_real_axes, grid)
#    1021 rechunked_padded_args = []
#    1022 for padded_arg, original_arg in zip(padded_args, original_args):
# -> 1023     original_arg_chunks = original_arg.variable.chunksizes
#    1024     merged_boundary_chunks = _get_chunk_pattern_for_merging_boundary(
#    1025         grid,
#    1026         padded_arg,
#    1027         original_arg_chunks,
#    1028         boundary_width_real_axes,
#    1029     )
#    1030     rechunked_arg = padded_arg.chunk(merged_boundary_chunks)
#
# AttributeError: 'dict' object has no attribute 'variable'

# %%
diff = grid.diff_2d_vector(
    {"X": URES_TRSP,
     "Y": VRES_TRSP},
)

UVRES_CONV3 = -(diff["X"] + diff["Y"]).compute()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 diff = grid.diff_2d_vector(
#       2     {"X": URES_TRSP,
#       3      "Y": VRES_TRSP},
#       4 )
#
# File ~/Library/CloudStorage/OneDrive-MassachusettsInstituteofTechnology/Documents/GitHub/xgcm/xgcm/grid.py:1274, in Grid.diff_2d_vector(self, vector, **kwargs)
#    1255 def diff_2d_vector(self, vector, **kwargs):
#    1256     """
#    1257     Difference a 2D vector to the intermediate grid point. This method is
#    1258     only necessary for complex grid topologies.
#    (...)   1272         are differenced vector components along each axis
#    1273     """
# -> 1274     return self._apply_vector_function(self.diff, vector, **kwargs)
#
# File ~/Library/CloudStorage/OneDrive-MassachusettsInstituteofTechnology/Documents/GitHub/xgcm/xgcm/grid.py:1240, in Grid._apply_vector_function(self, function, vector, **kwargs)
#    1237 x_axis_name, y_axis_name = list(vector)
#    1239 # apply for each component
# -> 1240 x_component = function(
#    1241     {x_axis_name: vector[x_axis_name]},
#    1242     x_axis_name,
#    1243     other_component={y_axis_name: vector[y_axis_name]},
#    1244     **kwargs,
#    1245 )
#    1247 y_component = function(
#    1248     {y_axis_name: vector[y_axis_name]},
#    1249     y_axis_name,
#    1250     other_component={x_axis_name: vector[x_axis_name]},
#    1251     **kwargs,
#    1252 )
#    1253 return {x_axis_name: x_component, y_axis_name: y_component}
#
# File ~/Library/CloudStorage/OneDrive-MassachusettsInstituteofTechnology/Documents/GitHub/xgcm/xgcm/grid.py:947, in Grid.diff(self, da, axis, **kwargs)
#     897 def diff(self, da, axis, **kwargs):
#     898     """
#     899     Difference neighboring points to the intermediate grid point.
#     900
#    (...)    945     >>> grid.diff(da, ["X", "Y"], fill_value={"X": 0, "Y": 100})
#     946     """
# --> 947     return self._1d_grid_ufunc_dispatch("diff", da, axis, **kwargs)
#
# File ~/Library/CloudStorage/OneDrive-MassachusettsInstituteofTechnology/Documents/GitHub/xgcm/xgcm/grid.py:689, in Grid._1d_grid_ufunc_dispatch(self, funcname, data, axis, to, keep_coords, metric_weighted, other_component, **kwargs)
#     686 else:
#     687     map_overlap = False
# --> 689 array = grid_ufunc(
#     690     self,
#     691     array,
#     692     axis=[(ax_name,)],
#     693     keep_coords=keep_coords,
#     694     dask=dask,
#     695     map_overlap=map_overlap,
#     696     other_component=other_component,
#     697     **remaining_kwargs,
#     698 )
#     700 if ax_metric_weighted:
#     701     metric = self.get_metric(array, ax_metric_weighted)
#
# File ~/Library/CloudStorage/OneDrive-MassachusettsInstituteofTechnology/Documents/GitHub/xgcm/xgcm/grid_ufunc.py:463, in GridUFunc.__call__(self, grid, axis, *args, **kwargs)
#     461 map_overlap = kwargs.pop("map_overlap", self.map_overlap)
#     462 pad_before_func = kwargs.pop("pad_before_func", self.pad_before_func)
# --> 463 return apply_as_grid_ufunc(
#     464     self.ufunc,
#     465     *args,
#     466     axis=axis,
#     467     grid=grid,
#     468     signature=self.signature,
#     469     boundary_width=self.boundary_width,
#     470     boundary=boundary,
#     471     dask=dask,
#     472     map_overlap=map_overlap,
#     473     pad_before_func=pad_before_func,
#     474     **kwargs,
#     475 )
#
# File ~/Library/CloudStorage/OneDrive-MassachusettsInstituteofTechnology/Documents/GitHub/xgcm/xgcm/grid_ufunc.py:767, in apply_as_grid_ufunc(func, axis, grid, signature, boundary_width, boundary, fill_value, keep_coords, dask, map_overlap, pad_before_func, other_component, *args, **kwargs)
#     764 # For most ufuncs we want to pad before applying, but for some (especially cumsum) we must apply then pad
#     765 # TODO could we bind a bunch of these arguments into a namedtuple/dataclass or something to save space?
#     766 if pad_before_func:
# --> 767     rechunked_padded_args = _pad_then_rechunk(
#     768         args,
#     769         grid,
#     770         in_core_dims,
#     771         boundary_width_real_axes,
#     772         boundary,
#     773         fill_value,
#     774         other_component,
#     775     )
#     776     results = _apply(
#     777         mapped_func,
#     778         rechunked_padded_args,
#    (...)    784         **kwargs,
#     785     )
#     786 else:  # pad after func
#
# File ~/Library/CloudStorage/OneDrive-MassachusettsInstituteofTechnology/Documents/GitHub/xgcm/xgcm/grid_ufunc.py:902, in _pad_then_rechunk(args, grid, in_core_dims, boundary_width_real_axes, boundary, fill_value, other_component)
#     885 padded_args = [
#     886     pad(
#     887         a,
#    (...)    894     for a, oc in zip(args, other_component)
#     895 ]
#     897 if any(
#     898     _has_chunked_core_dims(padded_arg, core_dims)
#     899     for padded_arg, core_dims in zip(padded_args, in_core_dims)
#     900 ):
#     901     # merge any lonely chunks on either end created by padding
# --> 902     rechunked_padded_args = _rechunk_to_merge_in_boundary_chunks(
#     903         padded_args,
#     904         args,
#     905         boundary_width_real_axes,
#     906         grid,
#     907     )
#     908 else:
#     909     rechunked_padded_args = padded_args
#
# File ~/Library/CloudStorage/OneDrive-MassachusettsInstituteofTechnology/Documents/GitHub/xgcm/xgcm/grid_ufunc.py:1023, in _rechunk_to_merge_in_boundary_chunks(padded_args, original_args, boundary_width_real_axes, grid)
#    1021 rechunked_padded_args = []
#    1022 for padded_arg, original_arg in zip(padded_args, original_args):
# -> 1023     original_arg_chunks = original_arg.variable.chunksizes
#    1024     merged_boundary_chunks = _get_chunk_pattern_for_merging_boundary(
#    1025         grid,
#    1026         padded_arg,
#    1027         original_arg_chunks,
#    1028         boundary_width_real_axes,
#    1029     )
#    1030     rechunked_arg = padded_arg.chunk(merged_boundary_chunks)
#
# AttributeError: 'dict' object has no attribute 'variable'

# %%
fig, ax = plt.subplots(1, 3, figsize = (15, 4))
UVRES_CONV.isel(k = 0, tile = 12).plot(ax = ax[0])
UVRES_CONV2.isel(k = 0, tile = 12).plot(ax = ax[1])
UVRES_CONV3.isel(k = 0, tile = 12).plot(ax = ax[2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 fig, ax = plt.subplots(1, 3, figsize = (15, 4))
#       2 UVRES_CONV.isel(k = 0, tile = 12).plot(ax = ax[0])
# ----> 3 UVRES_CONV2.isel(k = 0, tile = 12).plot(ax = ax[1])
#       4 UVRES_CONV3.isel(k = 0, tile = 12).plot(ax = ax[2])
#
# NameError: name 'UVRES_CONV2' is not defined

# %%
UVRES_CONV.sum(["tile", "i", "j"]).plot(label = "og", linestyle = "--", lw = 3)
UVRES_CONV2.sum(["tile", "i", "j"]).plot(label = "diff", linestyle = "--", lw = 2)
UVRES_CONV3.sum(["tile", "i", "j"]).plot(label = "diff2d", linestyle = "--", lw = 1)
plt.legend()
